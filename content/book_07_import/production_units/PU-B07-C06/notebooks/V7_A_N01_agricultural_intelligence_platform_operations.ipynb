# %% [markdown]
# # V7_A_N01 - Operate the Agricultural Intelligence Platform
#
# **SRAI Book 7 - Applied AI Studio: National Sector Intelligence**
# Controlled draft; synthetic data only. Specialist and institutional approval required.

# %% [markdown]
# ## Decision contract
# Operate a governed agricultural intelligence service across ingestion, validation, analysis, release, monitoring, and recovery. The notebook supports service management; it does not authorize publication, alter source records, or bypass statistical release authority.

# %%
import numpy as np, pandas as pd
rng=np.random.default_rng(7101); services=['ingest','validate','estimate','publish','backup','monitor']; df=pd.DataFrame({'service':services,'fresh_hours':rng.integers(1,40,6),'completeness':rng.uniform(.82,1,6),'reconciled':rng.choice([True,False],6,p=[.8,.2]),'job_ok':rng.choice([True,False],6,p=[.85,.15]),'owner':[f'OPS{i+1}' for i in range(6)]}); df

# %% [markdown]
# ## Evidence and quality contract
# Define source systems, jobs, dependencies, owners, schedules, service levels, data classifications, environments, access roles, incidents, backups, recovery objectives, release approvals, and retirement rules.

# %%
df['control_ok']=(df.fresh_hours<=24)&(df.completeness>=.95)&df.reconciled&df.job_ok; print(df[['service','fresh_hours','completeness','control_ok']].round(3).to_string(index=False))
# Out:
#  service  fresh_hours  completeness  control_ok
#   ingest           36         0.838       False
# validate           11         0.865       False
# estimate           26         0.914       False
#  publish           29         0.959       False
#   backup           11         0.913       False
#  monitor           17         0.845       False

# %% [markdown]
# ## Uncertainty, sensitivity, and abstention
# A green job status does not prove correct data or valid statistics. Combine freshness, completeness, reconciliation, execution, and review evidence; abstain from release when a critical control is unresolved.

# %%
release_ready=bool(df.control_ok.all()); status='CONTROLLED RELEASE REVIEW' if release_ready else 'ABSTAIN - RESOLVE PLATFORM CONTROLS'; exceptions=df.loc[~df.control_ok,['service','owner','fresh_hours','completeness','reconciled','job_ok']]; print(status); print(exceptions.round(3).to_string(index=False))
# Out:
# ABSTAIN - RESOLVE PLATFORM CONTROLS
#  service owner  fresh_hours  completeness  reconciled  job_ok
#   ingest  OPS1           36         0.838        True    True
# validate  OPS2           11         0.865       False    True
# estimate  OPS3           26         0.914       False    True
#  publish  OPS4           29         0.959       False    True
#   backup  OPS5           11         0.913        True    True
#  monitor  OPS6           17         0.845        True    True

# %% [markdown]
# ## Decision product and authority boundary
# The output is a traceable review queue with reason codes, evidence date, uncertainty, accountable owner, and status. It does not replace legal, professional, clinical, procurement, enforcement, safeguarding, budget, statistical-release, or ethical authority.

# %% [markdown]
# ## Exercises
# 1. Add recovery-point checks. 2. Separate technical success from statistical acceptance. 3. Design a release rollback.

# %% [markdown]
# ## Exact solutions
# 1. Compare the last verified backup and replicated checkpoint with the approved recovery-point objective. 2. Technical success means the workflow ran; statistical acceptance requires validated concepts, estimates, uncertainty, confidentiality, and authority. 3. Preserve the prior release, immutable inputs, code version, approvals, rollback owner, trigger, and post-incident review.

# %%
assert status and len(df)==6 and df.owner.notna().all(); print('V7_A_N01_COMPLETE_EXECUTION_PASS')
# Out:
# V7_A_N01_COMPLETE_EXECUTION_PASS
