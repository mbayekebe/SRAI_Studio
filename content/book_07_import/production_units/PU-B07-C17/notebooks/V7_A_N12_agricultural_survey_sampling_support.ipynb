# %% [markdown]
# # V7_A_N12 — Samples That Can Represent a Nation
#
# **SRAI Book 7 — Applied AI Studio: National Sector Intelligence**
# Controlled draft; synthetic data only. Specialist and institutional approval required.

# %% [markdown]
# ## Decision contract
# Support transparent agricultural survey design, allocation, and fieldwork monitoring. The notebook does not replace the legal sampling frame, professional sample-design approval, or disclosure rules.

# %%
import numpy as np,pandas as pd
rng=np.random.default_rng(7712);df=pd.DataFrame({'stratum':['Irrigated','Rainfed-N','Rainfed-S','Pastoral','Periurban'],'farms':[18000,72000,65000,28000,12000],'sd_yield':[1.1,1.8,2.0,2.5,1.4],'frame_age':[1,2,5,4,7]});n=600;df

# %% [markdown]
# ## Evidence and quality contract
# Define target population, frame, domains, strata, primary units, measures of size, inclusion probabilities, nonresponse, substitutions, weights, variance method, and release policy.

# %%
df['prop_n']=np.floor(n*df.farms/df.farms.sum()).astype(int);score=df.farms*df.sd_yield;df['neyman_n']=np.floor(n*score/score.sum()).astype(int);df['weight_prop']=df.farms/df.prop_n;df['quality']=df.frame_age<=5;print(df.to_string(index=False))
# Out:
#   stratum  farms  sd_yield  frame_age  prop_n  neyman_n  weight_prop  quality
# Irrigated  18000       1.1          1      55        32   327.272727     True
# Rainfed-N  72000       1.8          2     221       212   325.791855     True
# Rainfed-S  65000       2.0          5     200       212   325.000000     True
#  Pastoral  28000       2.5          4      86       114   325.581395     True
# Periurban  12000       1.4          7      36        27   333.333333    False

# %% [markdown]
# ## Uncertainty, sensitivity, and abstention
# Compare proportional and precision-oriented allocation. Small or weak-frame strata trigger minimum-sample review or abstention; design effects and nonresponse must be scenario-tested.

# %%
df['deff_n']=np.ceil(df.neyman_n*1.4/.85).astype(int);df['status']=np.where(~df.quality,'ABSTAIN—UPDATE FRAME',np.where(df.neyman_n<40,'MINIMUM SAMPLE REVIEW','DESIGN REVIEW'));result=df[['stratum','prop_n','neyman_n','deff_n','frame_age','status']];print(result.to_string(index=False));print('allocation_difference',int((df.prop_n-df.neyman_n).abs().sum()))
# Out:
#   stratum  prop_n  neyman_n  deff_n  frame_age                status
# Irrigated      55        32      53          1 MINIMUM SAMPLE REVIEW
# Rainfed-N     221       212     350          2         DESIGN REVIEW
# Rainfed-S     200       212     350          5         DESIGN REVIEW
#  Pastoral      86       114     188          4         DESIGN REVIEW
# Periurban      36        27      45          7  ABSTAIN—UPDATE FRAME
# allocation_difference 81

# %% [markdown]
# ## Decision product and authority boundary
# Produce a traceable review queue with reason codes, evidence date, uncertainty, accountable owner, and status. No model output substitutes for statutory, professional, clinical, procurement, enforcement, budget, or ethical authority.

# %% [markdown]
# ## Exercises
# 1. Explain why weights are required. 2. Add cluster design effects. 3. Design nonresponse adjustment.

# %% [markdown]
# ## Exact solutions
# 1. Unequal inclusion probabilities require inverse-probability weights for population inference. 2. Inflate the effective sample using justified intracluster correlation and cluster size assumptions. 3. Define response cells or a response-propensity model using pre-outcome variables, cap extreme adjustments, and validate bias/variance.

# %%
assert len(result)>0 and result['status'].notna().all();print('V7_A_N12_COMPLETE_EXECUTION_PASS')
# Out:
# V7_A_N12_COMPLETE_EXECUTION_PASS
