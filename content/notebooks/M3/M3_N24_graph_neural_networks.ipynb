# %% [markdown]
# # M3 Notebook 24 — Graph Neural Networks

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_dl import gcn_layer,graph_pool,message_passing

# %%
A=np.array([[0,1,1],[1,0,0],[1,0,0]],float)
X=np.eye(3); W=np.random.default_rng(24).normal(size=(3,4))
H=gcn_layer(A,X,W)
{'node_shape':H.shape,'graph_embedding':graph_pool(H)}

# %% [markdown]
# GNNs update node representations by aggregating messages from neighbors.

# %% [markdown]
# ## Key insight
#
# Graph neural networks learn from both attributes and relational structure.
