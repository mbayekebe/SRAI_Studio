# %% [markdown]
# # M3 Notebook 12 — Transformers
#
# **Status:** Runnable first edition

# %% [markdown]
# ## Learning objectives
#
# - Use positional encodings.
# - Build an encoder block.
# - Understand causal decoder attention.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_dl import parameter_count_transformer,positional_encoding,transformer_decoder_self_attention,transformer_encoder_block

# %%
pe=positional_encoding(50,16)
fig,ax=plt.subplots(figsize=(8,4)); ax.imshow(pe,aspect='auto'); ax.set_title('Positional Encoding'); plt.show()

# %%
rng=np.random.default_rng(12); X=rng.normal(size=(10,16))+positional_encoding(10,16); Y=transformer_encoder_block(X,4,32,12)
{'input':X.shape,'output':Y.shape,'mean':Y.mean(),'std':Y.std()}

# %%
_,w=transformer_decoder_self_attention(X,True)
w[:3,:3]

# %%
pd.Series({'small':parameter_count_transformer(64,256,4,6),'medium':parameter_count_transformer(512,2048,8,12)})

# %% [markdown]
# ## Key insight
#
# Transformers combine parallel self-attention, positional information, residual connections, and feed-forward transformations.
