# %% [markdown]
# # M3 Notebook 28 — Deep-Learning Deployment

# %% [markdown]
# ## Learning objectives
#
# - Quantize, prune, batch, and document a model.
# - Measure memory implications of deployment choices.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_dl import batch_inference,dequantize_symmetric,model_size_bytes,prune_by_magnitude,quantize_symmetric

# %%
rng=np.random.default_rng(28)
W=rng.normal(size=(256,128))
q,scale=quantize_symmetric(W,8)
reconstructed=dequantize_symmetric(q,scale)
pruned=prune_by_magnitude(W,.7)
{"float32_MB":model_size_bytes([W])/1e6,
 "int8_MB":q.nbytes/1e6,
 "quantization_MSE":np.mean((W-reconstructed)**2),
 "pruned_sparsity":np.mean(pruned==0)}

# %% [markdown]
# ## Key insight
#
# Deployment is an engineering optimization over latency, memory, accuracy, reliability, and maintainability.
