# %% [markdown]
# # M3 Notebook 29 — Responsible Deep Learning

# %% [markdown]
# ## Learning objectives
#
# - Evaluate subgroup gaps, confidence, robustness, privacy, and abstention.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_dl import confidence_abstention,demographic_parity_gap,equal_opportunity_gap,responsible_ai_checklist

# %%
y=np.array([0,1,1,0,1,0])
prob=np.array([[.8,.2],[.2,.8],[.55,.45],[.4,.6],[.1,.9],[.7,.3]])
pred=np.argmax(prob,axis=1)
groups=np.array(["A","A","A","B","B","B"])
abstained,confidence=confidence_abstention(prob,.6)
{"demographic_parity_gap":demographic_parity_gap(pred,groups),
 "equal_opportunity_gap":equal_opportunity_gap(y,pred,groups),
 "abstentions":int(np.sum(abstained==-1))}

# %% [markdown]
# ## Governance checklist

# %%
pd.Series(responsible_ai_checklist())

# %% [markdown]
# ## Key insight
#
# Responsible deep learning requires technical safeguards, documentation, oversight, and post-deployment monitoring.
