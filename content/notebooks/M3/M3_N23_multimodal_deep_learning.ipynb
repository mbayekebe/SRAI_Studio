# %% [markdown]
# # M3 Notebook 23 — Multimodal Deep Learning

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_dl import concatenate_fusion,gated_fusion,cosine_alignment

# %%
rng=np.random.default_rng(23)
text=rng.normal(size=(100,8)); image=rng.normal(size=(100,8))
fused=concatenate_fusion(text,image)
{'shape':fused.shape,'alignment':cosine_alignment(text,image)}

# %% [markdown]
# Multimodal systems combine complementary signals such as text, images, tabular data, and time series.

# %% [markdown]
# ## Key insight
#
# Fusion quality depends on alignment, missing modalities, and the decision context.
