# %% [markdown]
# # M3 Notebook 25 — Deep Reinforcement-Learning Foundations

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_dl import TinyDQN,discounted_returns,epsilon_greedy,q_update

# %%
q=np.zeros((3,2))
for _ in range(50): q=q_update(q,0,1,1,1,.2,.9)
{'Q':q,'returns':discounted_returns([1,0,2],.9)}

# %% [markdown]
# Deep RL combines function approximation with sequential decision-making under delayed rewards.

# %% [markdown]
# ## Key insight
#
# Reinforcement learning optimizes policies through interaction, not static labeled examples.
