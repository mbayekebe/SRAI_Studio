# %% [markdown]
# # M3 Notebook 22 — Self-Supervised Learning

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_dl import contrastive_pairs,nt_xent_loss,random_mask

# %%
X=np.random.default_rng(22).normal(size=(200,16))
a,b=contrastive_pairs(X,.1,22)
{'contrastive_loss':nt_xent_loss(a,b,.2),'masked_fraction':1-random_mask(X,.25,22)[1].mean()}

# %% [markdown]
# Self-supervision creates labels from the data itself through masking, augmentation, or temporal structure.

# %% [markdown]
# ## Key insight
#
# Self-supervised objectives learn reusable representations from unlabeled data.
