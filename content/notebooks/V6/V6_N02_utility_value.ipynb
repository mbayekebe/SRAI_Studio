# %% [markdown]
# # V6 Notebook 02 — Utility and Value

# %% [markdown]
# ## Learning objectives
#
# - Convert outcomes into value and utility.
# - Compare risk-neutral and risk-averse choices.
# - Estimate the value of information.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_decision import certainty_equivalent,expected_utility,exponential_utility,linear_utility,value_of_information

# %%
outcomes=np.array([0,50,100],float)
probabilities=np.array([.2,.5,.3])
linear=linear_utility(outcomes,0,100)
risk_averse=exponential_utility(outcomes,.02)
{"expected_value":expected_utility(outcomes,probabilities),
 "expected_linear_utility":expected_utility(outcomes,probabilities,lambda x:linear_utility(x,0,100)),
 "expected_risk_averse_utility":expected_utility(outcomes,probabilities,lambda x:exponential_utility(x,.02)),
 "value_of_information":value_of_information(84,76)}

# %% [markdown]
# ## Key insight
#
# Utility separates what an outcome is worth from the outcome's raw numerical magnitude.
