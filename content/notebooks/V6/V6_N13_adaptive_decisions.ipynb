# %% [markdown]
# # V6 Notebook 13 — Adaptive and Sequential Decisions

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_decision import adaptive_policy_score,epsilon_greedy,sequential_update,threshold_policy

# %%
mean,var=50,25; history=[]
for obs in [54,48,60,57]:
    mean,var=sequential_update(mean,var,obs,16)
    history.append({"observation":obs,"posterior_mean":mean,"posterior_variance":var,"action":threshold_policy(mean,55,"Maintain","Scale up")})
{"updates":pd.DataFrame(history),"chosen_arm":epsilon_greedy([.6,.8,.7],.05,13),"score":adaptive_policy_score([3,4,5,6])}

# %% [markdown]
# ## Key insight
#
# Adaptive decisions improve over time by combining learning, feedback, and updated actions.
