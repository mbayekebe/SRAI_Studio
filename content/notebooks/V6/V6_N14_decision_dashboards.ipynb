# %% [markdown]
# # V6 Notebook 14 — Decision Dashboards

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_decision import dashboard_readiness,decision_kpis,decision_register,traffic_light

# %%
kpis=decision_kpis(82,.28,1200000,.91)
register=decision_register([{"decision":"Approve pilot","owner":"Director","priority":.9},{"decision":"Review procurement","owner":"Finance","priority":.7},{"decision":"Update assumptions","owner":"Analytics","priority":.8}])
{"kpis":kpis,"signals":{"value":traffic_light(82,80,60,True),"risk":traffic_light(.28,.25,.4,False),"coverage":traffic_light(.91,.9,.75,True)},"register":register,"readiness":dashboard_readiness(True,True,True,True)}

# %% [markdown]
# ## Key insight
#
# A decision dashboard should show what must be decided, by whom, by when, and based on which evidence.
