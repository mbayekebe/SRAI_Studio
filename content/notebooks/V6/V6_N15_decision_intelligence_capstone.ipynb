# %% [markdown]
# # V6 Notebook 15 — Decision Intelligence Capstone

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_decision import decision_intelligence_architecture,decision_intelligence_scorecard,decision_readiness

# %%
scorecard=decision_intelligence_scorecard(.95,.88,.80,.84,.78)
checks={"decision_owner_defined":True,"alternatives_defined":True,"criteria_weighted":True,"uncertainty_simulated":True,"causal_evidence_reviewed":True,"optimization_completed":True,"dashboard_published":True,"governance_approved":False}
{"architecture":decision_intelligence_architecture(),"scorecard":scorecard,"readiness":decision_readiness(checks)}

# %% [markdown]
# ## Final Volume 6 insight
#
# Decision Intelligence integrates data, models, causal evidence, simulation, optimization, human judgment, and governance into a learning decision system.
