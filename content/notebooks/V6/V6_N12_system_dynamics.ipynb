# %% [markdown]
# # V6 Notebook 12 — System Dynamics

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_decision import carrying_capacity_growth,equilibrium,feedback_loop_gain,stock_flow_simulation

# %%
water=stock_flow_simulation(100,lambda t,s:20,lambda t,s:.12*s,20)
population=carrying_capacity_growth(10,.25,100,20)
{"water_stock":water,"population":population,"feedback_gain":feedback_loop_gain([1.2,.8,-.4]),"equilibrium":equilibrium(lambda x:20,lambda x:.12*x,np.linspace(0,300,1000))}

# %% [markdown]
# ## Key insight
#
# System dynamics explains how feedback and accumulation produce long-term policy effects.
