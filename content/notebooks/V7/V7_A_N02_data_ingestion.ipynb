# %% [markdown]
# # V7 Track A Notebook 02 — Agricultural Data Ingestion

# %% [markdown]
# ## Objective
#
# Build a repeatable ingestion process for agricultural data from heterogeneous sources.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_applied import bronze_silver_gold,ingest_csv_like,ingestion_manifest

# %%
records=[
    {"Region":"Oromia","Crop":"Corn","Area":1200,"Production":3600},
    {"Region":"Amhara","Crop":"Wheat","Area":900,"Production":1800},
    {"Region":"Oromia","Crop":"Corn","Area":1200,"Production":3600},
]
df=ingest_csv_like(records)
zones=bronze_silver_gold(df)
{"bronze_rows":len(zones["bronze"]),
 "silver_rows":len(zones["silver"]),
 "manifest":ingestion_manifest("annual_crop_survey",len(df),df.columns)}

# %% [markdown]
# ## Key insight
#
# Ingestion should preserve raw data, standardize structure, remove obvious duplication, and create auditable manifests.
