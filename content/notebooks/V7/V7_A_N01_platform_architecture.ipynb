# %% [markdown]
# # V7 Track A Notebook 01 — Platform Architecture

# %% [markdown]
# ## Objective
#
# Design the end-to-end architecture of a National Agricultural Intelligence Platform.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_applied import architecture_summary,reference_layers,select_deployment_mode

# %%
layers=reference_layers()
pd.DataFrame([
    {"layer":layer.name,"purpose":layer.purpose,"components":", ".join(layer.components)}
    for layer in layers
])

# %%
{"summary":architecture_summary(),
 "recommended_mode":select_deployment_mode(
     connectivity="limited",
     data_sensitivity="high",
     cloud_readiness="medium",
 )}

# %% [markdown]
# ## Key insight
#
# The platform must integrate official statistics, administrative data, geospatial data, market information, and AI services under one governance model.
