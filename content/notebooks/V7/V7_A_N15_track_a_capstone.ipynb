# %% [markdown]
# # V7 Track A Notebook 15 — National Agricultural Intelligence Platform Capstone

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_applied import capstone_architecture,implementation_readiness,intervention_priority,platform_scorecard

# %%
scorecard=platform_scorecard(.90,.84,.88,.80,.72)
checks={"core_sources_connected":True,"quality_rules_active":True,"forecasting_validated":True,"early_warning_operational":True,"remote_sensing_integrated":True,"census_module_ready":True,"sampling_support_ready":True,"food_security_module_ready":True,"governance_approved":False}
districts=pd.DataFrame({"district":["D1","D2","D3"],"risk":[.8,.6,.4],"population":[100000,80000,50000],"intervention_cost":[2000000,1200000,600000]})
districts["priority"]=intervention_priority(districts.risk,districts.population,districts.intervention_cost)
{"architecture":capstone_architecture(),"scorecard":scorecard,"readiness":implementation_readiness(checks),"intervention_priority":districts.sort_values("priority",ascending=False)}

# %% [markdown]
# ## Final Track A insight
#
# The National Agricultural Intelligence Platform unifies official statistics, forecasting, markets, climate, Earth observation, early warning, survey methods, and executive decision support.
