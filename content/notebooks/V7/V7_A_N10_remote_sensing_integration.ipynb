# %% [markdown]
# # V7 Track A Notebook 10 — Satellite and Remote-Sensing Integration

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_applied import crop_stress_score,eo_feature_table,evi,ndvi,vegetation_condition_index,zonal_statistics

# %%
nir=np.array([.7,.6,.4,.3,.8,.55])
red=np.array([.2,.25,.3,.28,.18,.35])
blue=np.array([.1,.12,.15,.14,.09,.2])
ndvi_values=ndvi(nir,red)
features=eo_feature_table(ndvi_values,[80,60,30,25,90,40],[24,25,29,31,23,28])
features["EVI"]=evi(nir,red,blue)
features["stress"]=crop_stress_score(ndvi_values,np.full(len(ndvi_values),.6))
features

# %%
zones=np.array(["A","A","A","B","B","B"])
{"zonal_stats":zonal_statistics(ndvi_values,zones),
 "VCI":vegetation_condition_index(ndvi_values,.1,.8)}

# %% [markdown]
# ## Key insight
#
# Earth-observation features add timely spatial evidence where field surveys are infrequent or incomplete.
