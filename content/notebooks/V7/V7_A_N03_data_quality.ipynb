# %% [markdown]
# # V7 Track A Notebook 03 — Agricultural Data Quality

# %% [markdown]
# ## Objective
#
# Evaluate completeness, consistency, uniqueness, ranges, and outliers.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_applied import completeness_report,consistency_checks,outlier_zscore,quality_score,range_check

# %%
df=pd.DataFrame({
    "region":["A","A","B","B"],
    "area":[10,0,20,None],
    "production":[30,5,-1,60],
    "male":[5,4,7,6],
    "female":[5,6,8,4],
    "total":[10,10,15,11],
})
{"completeness":completeness_report(df),
 "consistency":consistency_checks(df),
 "quality_score":quality_score(df,["region","area","production"]),
 "area_range_failures":range_check(df["area"],0,100).tolist(),
 "production_outliers":outlier_zscore(df["production"].fillna(0)).tolist()}

# %% [markdown]
# ## Key insight
#
# Data quality must be measured continuously and linked to correction workflows, not treated as a one-time cleaning activity.
