# %% [markdown]
# # V7 Track A Notebook 04 — Core Agricultural Analytics

# %% [markdown]
# ## Objective
#
# Compute production, area, yield, indices, and food-security risk indicators.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_applied import aggregate_crop_performance,classify_risk,food_security_risk_score,production_index,yield_per_hectare

# %%
df=pd.DataFrame({
    "region":["Oromia","Oromia","Amhara","Amhara"],
    "crop":["maize","wheat","maize","wheat"],
    "area":[1200,700,900,800],
    "production":[3600,1400,1800,1600],
})
with_yield=yield_per_hectare(df)
performance=aggregate_crop_performance(with_yield)
performance

# %%
risk=food_security_risk_score(
    price_change=[.4,.1,.6],
    rainfall_anomaly=[-.5,.1,-.8],
    production_change=[-.3,.2,-.5],
)
pd.DataFrame({
    "risk_score":risk,
    "risk_level":[classify_risk(v) for v in risk],
})

# %% [markdown]
# ## Key insight
#
# Core agricultural intelligence begins with transparent official indicators before progressing to advanced AI.
