# %% [markdown]
# # V7 Track A Notebook 11 — Agricultural Census Intelligence

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_applied import census_consistency_flags,coverage_rate,nonresponse_rate,regional_census_summary,structural_indicator_table

# %%
df=pd.DataFrame({"holding_id":[1,2,3,4],"region":["A","A","B","B"],"area":[2.5,5,3,7.5],"manager_sex":["female","male","female","male"],"irrigated":[1,0,0,1],"crop_area":[2,6,2,5],"total_area":[2.5,5,3,7.5],"livestock_total":[4,10,6,12],"cattle":[2,11,3,5]})
{"coverage":coverage_rate([100,120],[95,108]),"nonresponse":nonresponse_rate([100,120],[92,105]),"indicators":structural_indicator_table(df),"flags":census_consistency_flags(df),"regional":regional_census_summary(df)}

# %% [markdown]
# ## Key insight
#
# Agricultural census intelligence combines coverage control, structural indicators, consistency checks, and regional summaries.
