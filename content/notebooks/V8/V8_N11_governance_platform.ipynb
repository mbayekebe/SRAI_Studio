# %% [markdown]
# # V8 Notebook 11 — Enterprise AI Governance Platform

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_enterprise import approval_workflow,governance_register,model_card,risk_tier

# %%
tier=risk_tier("high","semi","high")
card=model_card("RiskModel","1.0","AI Office","Prioritize inspections",["Not for autonomous sanctions"],{"AUC":.88})
{"risk_tier":tier,
 "model_card":card,
 "approval":approval_workflow(["Data Owner","Risk","Legal"],["Data Owner","Risk"]),
 "register":governance_register([{"name":"RiskModel","risk_tier":tier},{"name":"Assistant","risk_tier":"medium"}])}

# %% [markdown]
# ## Key insight
#
# A governance platform operationalizes model inventory, risk tiering, documentation, and approval workflows.
