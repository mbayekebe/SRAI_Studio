# %% [markdown]
# # V8 Notebook 05 — Identity, Security, and Zero Trust

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_enterprise import audit_event,authorize,zero_trust_score

# %%
permissions={
    "analyst":["read:dataset","analyze:dataset"],
    "administrator":["read:dataset","delete:dataset"],
}
user={"id":"u-17","roles":["analyst"],"clearance":"high","suspended":False}
resource={"id":"agri-census","type":"dataset","classification":"restricted"}
decision=authorize(user,resource,"read",permissions)
{"authorization":decision,
 "zero_trust_score":zero_trust_score(True,True,False,True,True),
 "audit":audit_event(user["id"],"read",resource["id"],decision["allowed"])}

# %% [markdown]
# ## Key insight
#
# Enterprise AI requires identity verification, least privilege, contextual authorization, and complete auditability.
