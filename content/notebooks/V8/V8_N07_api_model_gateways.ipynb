# %% [markdown]
# # V8 Notebook 07 — API and Model Gateway Engineering

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_enterprise import circuit_breaker,gateway_policy,model_fallback,rate_limit,route_model

# %%
allowed_models={"analyst":["general-model","reasoning-model"],"admin":["private-model","reasoning-model"]}
{"route":route_model("reasoning","low","low"),
 "rate_limit":rate_limit(75,100),
 "circuit_breaker":circuit_breaker(.12,.2),
 "policy":gateway_policy({"role":"analyst"},"reasoning-model",allowed_models),
 "fallback":model_fallback("down",["backup-model"])}

# %% [markdown]
# ## Key insight
#
# Gateways centralize routing, policy enforcement, resilience, quotas, and model abstraction.
