# %% [markdown]
# # V8 Notebook 04 — Event-Driven AI Systems

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_enterprise import Event,EventBus,event_lag_seconds,idempotency_key

# %%
bus=EventBus()
bus.subscribe("risk_alert",lambda event:{"action":"create_case","entity":event["entity_id"]})
bus.subscribe("risk_alert",lambda event:{"action":"notify_owner","score":event["payload"]["score"]})
event=Event("risk_alert","D17",{"score":.87,"version":"3"},timestamp=1000)
{"idempotency_key":idempotency_key(event),
 "handler_results":bus.publish(event),
 "lag_seconds":event_lag_seconds(1000,1012.5),
 "history":bus.history}

# %% [markdown]
# ## Key insight
#
# Event-driven systems respond to changes in near real time and decouple producers from AI consumers.
