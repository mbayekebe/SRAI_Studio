# %% [markdown]
# # V8 Notebook 08 — Enterprise AI Microservices

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_enterprise import Service,deployment_units,health_summary,saga_result,service_graph

# %%
services=[
 Service("ingestion","Load enterprise data",[],2),
 Service("retrieval","Search enterprise knowledge",["ingestion"],3),
 Service("assistant","Answer governed questions",["retrieval"],4),
]
{"graph":service_graph(services),
 "deployments":deployment_units(services),
 "health":health_summary({"ingestion":"healthy","retrieval":"healthy","assistant":"degraded"}),
 "saga":saga_result([{"name":"validate","status":"ok"},{"name":"publish","status":"failed"}])}

# %% [markdown]
# ## Key insight
#
# Microservices isolate responsibilities and scale independently, but require health management and distributed-transaction controls.
