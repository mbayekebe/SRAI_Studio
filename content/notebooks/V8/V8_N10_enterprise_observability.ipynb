# %% [markdown]
# # V8 Notebook 10 — Enterprise Observability and Telemetry

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_enterprise import aggregate_traces,anomaly_flag,service_level_objective,trace

# %%
traces=[
 trace("1","retrieval",120,"ok",500,.02),
 trace("2","assistant",850,"ok",1200,.08),
 trace("3","assistant",1400,"error",900,.06),
]
{"aggregate":aggregate_traces(traces),
 "SLO":service_level_objective([120,850,1400],1000,.66),
 "anomaly":anomaly_flag(1400,700,200,3)}

# %% [markdown]
# ## Key insight
#
# Enterprise observability links traces, latency, errors, tokens, cost, and service objectives.
