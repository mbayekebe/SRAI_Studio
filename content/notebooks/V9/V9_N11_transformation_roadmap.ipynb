# %% [markdown]
# # V9 Notebook 11 — AI Transformation Roadmap

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import dependency_check,milestone_status,transformation_roadmap

# %%
initiatives=[
 {"name":"Establish AI governance","phase":"Mobilize","priority":.9,"dependencies":[]},
 {"name":"Build data exchange","phase":"Foundation","priority":.85,"dependencies":["Establish AI governance"]},
 {"name":"Launch forecasting pilot","phase":"Pilot","priority":.8,"dependencies":["Build data exchange"]},
 {"name":"Scale shared AI platform","phase":"Scale","priority":.9,"dependencies":["Launch forecasting pilot"]},
]
{"roadmap":transformation_roadmap(initiatives),"dependencies":dependency_check(initiatives),"status":milestone_status(7,10)}

# %% [markdown]
# ## Key insight
#
# Transformation roadmaps sequence governance, foundations, pilots, scale, and institutionalization.
