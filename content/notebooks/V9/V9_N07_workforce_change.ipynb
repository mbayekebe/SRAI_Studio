# %% [markdown]
# # V9 Notebook 07 — Workforce and Change Management

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import change_readiness,learning_path,skills_gap

# %%
current={"AI literacy":2,"data governance":1,"MLOps":1,"decision intelligence":2}
target={"AI literacy":4,"data governance":4,"MLOps":3,"decision intelligence":4}
{"skills_gap":skills_gap(current,target),
 "executive_path":learning_path("executive"),
 "technical_path":learning_path("technical"),
 "change_readiness":change_readiness(True,True,False,True,True)}

# %% [markdown]
# ## Key insight
#
# AI transformation depends on skills, participation, incentives, communication, and redesigned work—not technology alone.
