# %% [markdown]
# # V9 Notebook 14 — Sustainable AI Transformation

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import carbon_estimate,sustainability_actions,sustainability_score

# %%
{"sustainability_score":sustainability_score(.75,.8,.7,.85,.9),
 "estimated_carbon":carbon_estimate(500,2.5,.45),
 "actions":sustainability_actions()}

# %% [markdown]
# ## Key insight
#
# Sustainable AI requires efficient models, durable financing, responsible infrastructure, local capability, and continuing public value.
