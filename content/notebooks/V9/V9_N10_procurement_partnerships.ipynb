# %% [markdown]
# # V9 Notebook 10 — AI Procurement and Partnerships

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import contract_clauses,partnership_model,rank_vendors

# %%
vendors=[
 {"name":"Vendor A","functional_fit":.9,"security":.8,"interoperability":.7,"total_cost":.6,"capacity_transfer":.8},
 {"name":"Vendor B","functional_fit":.8,"security":.9,"interoperability":.9,"total_cost":.75,"capacity_transfer":.6},
]
{"ranking":rank_vendors(vendors),
 "clauses":contract_clauses(),
 "partnership_model":partnership_model("high","medium","high")}

# %% [markdown]
# ## Key insight
#
# Good AI procurement protects data, interoperability, audit rights, portability, and long-term local capacity.
