# %% [markdown]
# # V9 Notebook 03 — AI Operating Model

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import governance_forum,operating_model_pattern,raci_matrix,team_topology

# %%
activities=["approve use case","build model","validate model","operate service"]
roles=["Executive","Domain","AI CoE","Risk"]
assignments={"approve use case":{"Executive":"A","Domain":"R","Risk":"C"},"build model":{"AI CoE":"R","Domain":"C"},"validate model":{"Risk":"R","Executive":"A"},"operate service":{"Domain":"R","AI CoE":"C"}}
{"pattern":operating_model_pattern("medium","high",True),
 "RACI":pd.DataFrame(raci_matrix(activities,roles,assignments)),
 "forum":governance_forum("AI Steering Committee","monthly",roles,["portfolio","risk","investment"]),
 "teams":team_topology()}

# %% [markdown]
# ## Key insight
#
# An AI operating model clarifies ownership, decision rights, shared platforms, and domain accountability.
