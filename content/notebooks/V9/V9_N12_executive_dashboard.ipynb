# %% [markdown]
# # V9 Notebook 12 — Executive AI Dashboard

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import board_readiness,executive_kpis,executive_signal,initiative_register

# %%
kpis=executive_kpis(8.5e6,.72,.28,.81,.68)
register=initiative_register([
 {"initiative":"National forecasting","status":"on track","priority":.9},
 {"initiative":"AI governance","status":"at risk","priority":.95},
 {"initiative":"Executive copilot","status":"on track","priority":.7},
])
{"kpis":kpis,
 "signals":{"adoption":executive_signal(kpis["adoption"],.75,.6,True),"risk":executive_signal(kpis["risk_exposure"],.2,.35,False)},
 "register":register,
 "board_readiness":board_readiness(True,True,True,True,False)}

# %% [markdown]
# ## Key insight
#
# Executive dashboards focus leadership attention on value, adoption, risk, delivery, talent, and decisions.
