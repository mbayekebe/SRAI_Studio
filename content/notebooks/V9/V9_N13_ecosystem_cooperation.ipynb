# %% [markdown]
# # V9 Notebook 13 — AI Ecosystems and International Cooperation

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import cooperation_priority,ecosystem_map,partnership_principles

# %%
{"ecosystem":ecosystem_map(
 ["Digital ministry","Statistics office"],
 ["National university"],
 ["Telecom","Local startups"],
 ["Consumer groups"],
 ["UN agencies","Development banks"],
 ),
 "cooperation_priority":cooperation_priority(.9,.7,.8,.85),
 "principles":partnership_principles()}

# %% [markdown]
# ## Key insight
#
# Strong AI ecosystems combine public leadership, research, enterprise, civil society, and international cooperation under local ownership.
