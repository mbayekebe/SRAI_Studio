# %% [markdown]
# # V9 Notebook 05 — AI Value Realization

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import benefit_register,net_present_value,roi,value_realization_score

# %%
benefits=[{"name":"Processing time reduction","value":500000},{"name":"Error reduction","value":250000},{"name":"Risk avoidance","value":400000}]
{"ROI":roi(1150000,600000),
 "NPV":net_present_value([-600000,300000,400000,500000],.08),
 "benefit_register":benefit_register(benefits),
 "value_score":value_realization_score(.8,.9,.85,.7)}

# %% [markdown]
# ## Key insight
#
# Value realization tracks financial, service, risk, and institutional benefits beyond technical model metrics.
