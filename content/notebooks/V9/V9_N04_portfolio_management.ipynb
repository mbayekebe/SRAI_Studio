# %% [markdown]
# # V9 Notebook 04 — AI Portfolio Management

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import expected_portfolio_value,portfolio_balance,prioritize_use_cases

# %%
use_cases=[
 {"name":"Inspection prioritization","category":"risk","value":.9,"feasibility":.8,"data_readiness":.8,"risk":.3,"time_to_value":.3},
 {"name":"Executive assistant","category":"productivity","value":.7,"feasibility":.9,"data_readiness":.7,"risk":.4,"time_to_value":.2},
 {"name":"National forecasting","category":"planning","value":.95,"feasibility":.6,"data_readiness":.6,"risk":.25,"time_to_value":.5},
]
portfolio=prioritize_use_cases(use_cases)
{"priorities":portfolio,"balance":portfolio_balance(portfolio),"expected_value":expected_portfolio_value([100,80,150],[.8,.75,.7],[35,25,70])}

# %% [markdown]
# ## Key insight
#
# Portfolio management balances value, feasibility, readiness, risk, time to value, and strategic diversity.
