# %% [markdown]
# # V9 Notebook 01 — AI Strategy and Transformation

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import initiative_fit,roadmap_phases,strategic_alignment_score,strategic_pillars

# %%
{"pillars":strategic_pillars(),
 "alignment":strategic_alignment_score(.95,.85,.75,.80,.78),
 "initiative_fit":initiative_fit(.9,.7,.2,.85),
 "roadmap_phases":roadmap_phases()}

# %% [markdown]
# ## Key insight
#
# AI strategy connects institutional mission, outcomes, foundations, governance, people, and delivery.
