# %% [markdown]
# # V9 Notebook 08 — National AI Platforms

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import national_ai_layers,platform_readiness,public_value_score,sovereignty_pattern

# %%
{"layers":national_ai_layers(),
 "sovereignty_pattern":sovereignty_pattern("high","medium",True),
 "public_value":public_value_score(.85,.9,.8,.8,.75),
 "readiness":platform_readiness(True,True,True,False,True)}

# %% [markdown]
# ## Key insight
#
# A national AI platform combines shared digital foundations, sovereign controls, sector data products, and public-service applications.
