# %% [markdown]
# # V9 Notebook 06 — Responsible AI Leadership

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import ethics_review,executive_risk_acceptance,leadership_commitments

# %%
{"commitments":leadership_commitments(),
 "risk_acceptance":executive_risk_acceptance("high",True,True),
 "ethics_review":ethics_review(.9,.2,.8,.75)}

# %% [markdown]
# ## Key insight
#
# Responsible leadership preserves human accountability and makes ethics and risk explicit executive responsibilities.
