# %% [markdown]
# # V9 Notebook 09 — Public-Sector AI Implementation

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import administrative_readiness,implementation_stage,service_prioritization

# %%
{"service_score":service_prioritization(.9,.85,.7,.25),
 "readiness":administrative_readiness(True,.85>=.8,True,True,True),
 "pilot_stage":implementation_stage("pilot"),
 "scale_stage":implementation_stage("scale")}

# %% [markdown]
# ## Key insight
#
# Public-sector AI must align legal authority, administrative processes, service design, budgets, and institutional ownership.
