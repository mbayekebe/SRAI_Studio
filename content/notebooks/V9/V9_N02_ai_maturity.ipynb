# %% [markdown]
# # V9 Notebook 02 — AI Maturity Assessment

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_strategy import assess_maturity,maturity_gaps,next_best_capabilities

# %%
current={"strategy":.7,"data":.45,"technology":.55,"talent":.35,"governance":.5,"delivery":.4}
target={k:.8 for k in current}
gaps=maturity_gaps(current,target)
{"assessment":assess_maturity(current),"gaps":gaps,"next_capabilities":next_best_capabilities(gaps,3)}

# %% [markdown]
# ## Key insight
#
# Maturity assessment identifies the institutional capabilities that must improve before AI can scale.
