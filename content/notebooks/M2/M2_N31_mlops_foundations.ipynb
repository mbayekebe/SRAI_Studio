# %% [markdown]
# # M2 Notebook 31 — MLOps Foundations
#
# **Status:** Runnable first edition

# %% [markdown]
# ## Learning objectives
#
# - Version datasets and models.
# - Create model cards.
# - Define deployment and rollback controls.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_ml import dataset_signature,deployment_checklist,model_card,save_json_artifact
from pathlib import Path

# %%
rng=np.random.default_rng(31)
X=rng.normal(size=(500,5)); y=(X[:,0]+X[:,1]>0).astype(int)
signature=dataset_signature(X,y)
signature

# %%
card=model_card('service-risk-classifier','1.0.0',{'accuracy':.87},['gap','distance'],['synthetic demonstration'],'human review prioritization')
path=save_json_artifact(card,Path('artifacts')/'m2_r7_model_card.json')
path

# %%
pd.Series(deployment_checklist(),name='required_control')

# %% [markdown]
# ## Key insight
#
# MLOps makes machine learning reproducible, deployable, observable, and governable.
