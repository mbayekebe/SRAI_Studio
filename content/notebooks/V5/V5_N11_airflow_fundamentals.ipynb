# %% [markdown]
# # V5 Notebook 11 — Airflow Fundamentals

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_mlops import AirflowTask,DAGSpec,airflow_dag_stub,backfill_dates

# %%
dag=DAGSpec("agri_retraining","0 2 * * 1","2026-01-01",False)
dag.add_task(AirflowTask("extract")).add_task(AirflowTask("validate",upstream=["extract"])).add_task(AirflowTask("train",retries=2,upstream=["validate"])).add_task(AirflowTask("register",upstream=["train"]))
{"spec":airflow_dag_stub(dag),"execution_order":dag.execution_order(),"backfill_dates":backfill_dates("2026-01-01","2026-01-05")}

# %% [markdown]
# ## Key insight
#
# Airflow models production workflows as scheduled, dependency-aware DAGs.
