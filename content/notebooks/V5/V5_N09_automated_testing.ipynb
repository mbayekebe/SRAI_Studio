# %% [markdown]
# # V5 Notebook 09 — Automated Testing for ML Systems

# %%
from srai_math.utils import environment_info,set_seed
from pathlib import Path
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_mlops import assert_no_nan,assert_shape,data_contract_check,model_regression_check,prediction_tolerance

# %%
X=pd.DataFrame({"rainfall":[100,80,60],"ndvi":[.7,.6,.4],"price_index":[110,120,135]})
{"contract":data_contract_check(X,["rainfall","ndvi","price_index"]),"shape":assert_shape(X.to_numpy(),(3,3)),"no_nan":assert_no_nan(X.to_numpy()),"tolerance":prediction_tolerance(.801,.800,.01),"regression":model_regression_check(.87,.88,.02)}

# %% [markdown]
# ## Key insight
#
# ML testing must cover code, data, models, interfaces, and deployment behavior.
