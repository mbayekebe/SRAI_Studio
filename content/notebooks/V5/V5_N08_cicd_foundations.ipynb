# %% [markdown]
# # V5 Notebook 08 — CI/CD Foundations

# %%
from srai_math.utils import environment_info,set_seed
from pathlib import Path
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_mlops import deployment_gate,github_actions_workflow,semantic_version_bump

# %%
{"workflow":github_actions_workflow(),"gate":deployment_gate(True,.91,.85,True),"next_patch":semantic_version_bump("1.4.2","patch"),"next_minor":semantic_version_bump("1.4.2","minor")}

# %% [markdown]
# ## Key insight
#
# CI/CD converts quality rules into automated, repeatable promotion decisions.
