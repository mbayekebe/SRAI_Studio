# %% [markdown]
# # V5 Notebook 06 — Docker for ML Systems

# %%
from srai_math.utils import environment_info,set_seed
from pathlib import Path
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_mlops import generate_dockerfile,generate_dockerignore,image_size_estimate,write_container_files

# %%
text=generate_dockerfile(app_module="app:app",port=8000)
paths=write_container_files(Path("artifacts")/"v5_docker_demo",text,generate_dockerignore())
{"dockerfile":text,"files":[str(p) for p in paths],"estimated_image_mb":image_size_estimate(120,180,35)}

# %% [markdown]
# ## Key insight
#
# Containers package code, dependencies, and runtime assumptions into a repeatable deployment unit.
