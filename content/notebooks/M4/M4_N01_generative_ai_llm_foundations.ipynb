# %% [markdown]
# # M4 Notebook 01 — Generative AI and LLM Foundations

# %% [markdown]
# ## Learning objectives
#
# - Distinguish generative and discriminative models.
# - Understand tokens, context, next-token prediction, and decoding.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_genai import WordTokenizer,token_statistics

# %%
texts=[
    "Generative AI predicts and creates new content.",
    "Large language models operate over tokens.",
    "Context influences the next-token distribution.",
]
tokenizer=WordTokenizer().fit(texts)
encoded=[tokenizer.encode(t) for t in texts]
{"vocabulary_size":len(tokenizer.itos_),
 "statistics":token_statistics(texts,tokenizer),
 "first_sequence":encoded[0]}

# %% [markdown]
# ## Foundation-model lifecycle
#
# Pretraining → instruction tuning → alignment → evaluation → deployment → monitoring.

# %% [markdown]
# ## Key insight
#
# An LLM is fundamentally a probabilistic sequence model embedded within a much larger data, training, alignment, and deployment system.
