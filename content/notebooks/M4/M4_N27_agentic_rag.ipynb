# %% [markdown]
# # M4 Notebook 27 — Agentic RAG

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_genai import AgenticRAGController,evidence_grade,retrieval_decision

# %%
docs=[{"text":"Agricultural census collects farm, crop, land, and livestock data.","score":.7}]
controller=AgenticRAGController(lambda q,k:docs if "census" in q.lower() else [],grader=lambda q,h:evidence_grade(q,h,.2))
{"needed":retrieval_decision("According to the document, what does the census collect?"),"result":controller.run("What does the census collect?",2,3)}

# %% [markdown]
# ## Key insight
#
# Agentic RAG dynamically chooses retrieval, query reformulation, evidence grading, and stopping.
