# %% [markdown]
# # M4 Notebook 10 — Grounded Answer Generation

# %% [markdown]
# ## Learning objectives
#
# - Assess answerability.
# - Measure citation coverage.
# - Flag unsupported claims.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_genai import answerability_score,citation_coverage,hallucination_flags

# %%
retrieved=[
    {"source_id":0,"chunk_id":0,"text":"The agricultural census collects data on farms, land, crops, and livestock."},
    {"source_id":1,"chunk_id":2,"text":"The census supports national agricultural planning."},
]
query="What does the agricultural census collect?"
answer="The census collects information on farms, land, crops, and livestock [Source 0]. It is conducted every year [Source 2]."
{"answerability":answerability_score(query,retrieved),
 "citation_coverage":citation_coverage(answer),
 "claim_checks":hallucination_flags(answer,[r["text"] for r in retrieved])}

# %% [markdown]
# ## Grounding controls
#
# A grounded system should retrieve evidence, refuse unsupported questions, cite sources, and separate evidence from inference.

# %% [markdown]
# ## Key insight
#
# Grounded generation is a controlled evidence-to-answer process, not merely fluent text production.
