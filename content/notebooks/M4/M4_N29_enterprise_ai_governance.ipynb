# %% [markdown]
# # M4 Notebook 29 — Enterprise AI Governance

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_genai import approval_gate,audit_record,governance_controls,risk_classification

# %%
risk=risk_classification("high","semi_autonomous","high")
gate=approval_gate({"groundedness":.91,"safety_incidents":0},{"groundedness":{"direction":"min","value":.85},"safety_incidents":{"direction":"max","value":0}})
{"risk":risk,"controls":governance_controls(risk),"gate":gate,"audit":audit_record("Enterprise Assistant","1.0","AI Office",risk,gate["approved"])}

# %% [markdown]
# ## Key insight
#
# Enterprise AI governance converts policy into ownership, controls, evidence, approval gates, and auditability.
