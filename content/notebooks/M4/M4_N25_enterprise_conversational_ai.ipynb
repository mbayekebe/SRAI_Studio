# %% [markdown]
# # M4 Notebook 25 — Enterprise Conversational AI

# %% [markdown]
# ## Learning objectives
#
# - Maintain conversation state and permissions.
# - Route enterprise intents.
# - Apply confidence-based escalation.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_genai import ConversationState,add_message,conversation_summary,escalation_required,permission_check,route_intent

# %%
state=ConversationState(
    user_id="manager_01",
    permissions={"finance.read","enterprise.read"},
)
add_message(state,"user","Show revenue and expenditure risks for the quarter.")
intent=route_intent(state.messages[-1]["content"])
{"intent":intent,
 "authorized":permission_check(state,"finance.read"),
 "escalation":escalation_required(.72,"medium"),
 "summary":conversation_summary(state.messages)}

# %% [markdown]
# ## Enterprise controls
#
# Identity → authorization → retrieval scope → audit logs → confidence thresholds → human escalation.

# %% [markdown]
# ## Key insight
#
# Enterprise assistants must combine conversational quality with permissions, evidence, workflow integration, and accountability.
