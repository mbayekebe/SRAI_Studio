# %% [markdown]
# # M4 Notebook 24 — Production LLM Architecture

# %% [markdown]
# ## Learning objectives
#
# - Design a reference architecture.
# - Route tasks by complexity and sensitivity.
# - Plan resilience and capacity.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_genai import capacity_estimate,reference_architecture,resilience_plan,routing_decision

# %%
pd.DataFrame([component.__dict__ for component in reference_architecture()])

# %%
scenarios=[
    {"task_complexity":"low","sensitivity":"low","latency_priority":"high"},
    {"task_complexity":"high","sensitivity":"low","latency_priority":"low"},
    {"task_complexity":"high","sensitivity":"high","latency_priority":"low"},
]
pd.DataFrame([
    {**s,"route":routing_decision(**s)}
    for s in scenarios
])

# %%
{"capacity":capacity_estimate(25,1.2,.4),
 "resilience":resilience_plan()}

# %% [markdown]
# ## Key insight
#
# Production LLM systems require orchestration, routing, guardrails, retrieval, resilience, observability, and governance.
