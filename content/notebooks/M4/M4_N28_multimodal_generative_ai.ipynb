# %% [markdown]
# # M4 Notebook 28 — Multimodal Generative AI

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
set_seed(42)
environment_info()
from srai_genai import cross_modal_similarity,fuse_embeddings,image_grounded_prompt,modality_missing_mask

# %%
rng=np.random.default_rng(28); text=rng.normal(size=(5,8)); image=text+rng.normal(scale=.1,size=(5,8))
{"fused_shape":fuse_embeddings(text,image).shape,"similarity":np.diag(cross_modal_similarity(text,image)),"status":modality_missing_mask(True,True),"prompt":image_grounded_prompt("What is visible?","A field with crop rows.","Plot 12")}

# %% [markdown]
# ## Key insight
#
# Multimodal systems align and combine evidence across text, images, audio, and structured data.
