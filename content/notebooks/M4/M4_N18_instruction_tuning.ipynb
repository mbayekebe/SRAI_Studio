# %% [markdown]
# # M4 Notebook 18 — Instruction Tuning

# %% [markdown]
# ## Learning objectives
#
# - Format instruction–input–response examples.
# - Mask prompt tokens from the response loss.
# - Evaluate instruction-data quality.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_genai import build_instruction_dataset,curriculum_sort,instruction_quality_check,response_only_mask

# %%
rows=[
    {
        "instruction":"Summarize the monitoring note.",
        "input":"Revenue increased, but debt-service delays remain.",
        "output":"Revenue improved; debt-service delays remain a risk.",
    },
    {
        "instruction":"Classify the issue.",
        "input":"No named owner for model monitoring.",
        "output":"Governance",
    },
]
dataset=build_instruction_dataset(rows)
dataset[0]

# %%
{"quality":[instruction_quality_check(row) for row in rows],
 "curriculum":[r["instruction"] for r in curriculum_sort(rows)],
 "mask":response_only_mask([1,2,3,4],[5,6])}

# %% [markdown]
# ## Key insight
#
# Instruction tuning teaches a model to follow task descriptions by training on carefully structured demonstrations.
