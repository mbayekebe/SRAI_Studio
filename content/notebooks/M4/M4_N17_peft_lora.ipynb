# %% [markdown]
# # M4 Notebook 17 — Parameter-Efficient Fine-Tuning and LoRA

# %% [markdown]
# ## Learning objectives
#
# - Understand low-rank adaptation.
# - Compare trainable parameter counts.
# - Apply adapter bottlenecks.

# %%
from srai_math.utils import environment_info,set_seed
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
set_seed(42)
environment_info()
from srai_genai import LoRALinear,lora_parameter_savings

# %%
dimensions=[
    (768,768,4),
    (4096,4096,8),
    (8192,8192,16),
]
pd.DataFrame([
    {"input":i,"output":o,"rank":r,**lora_parameter_savings(i,o,r)}
    for i,o,r in dimensions
])

# %%
base=np.random.default_rng(17).normal(size=(8,6))
layer=LoRALinear(base,rank=2,alpha=4,seed=17)
X=np.random.default_rng(18).normal(size=(5,8))
{"output_shape":layer.forward(X).shape,
 "trainable_parameters":layer.trainable_parameter_count(),
 "full_parameters":layer.full_parameter_count()}

# %% [markdown]
# ## Key insight
#
# LoRA adapts a large frozen weight matrix through a small trainable low-rank update.
